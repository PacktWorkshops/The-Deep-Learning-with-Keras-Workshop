# %%
# Import the data
import pandas as pd
df = pd.read_csv("../data/pacific_hurricanes.csv")
df.head()
# Out:
#          Date  hurricane
# 0  1949-06-11          0
# 1  1949-06-12          0
# 2  1949-06-13          0
# 3  1949-06-14          0
# 4  1949-06-15          0

# %% [markdown]
# Print out the value counts

# %%
df['hurricane'].value_counts()
# Out:
# 0    22435
# 1     1842
# Name: hurricane, dtype: int64

# %% [markdown]
# Count the normalized values and index the value count corresponding to hurricane value 0

# %%
df['hurricane'].value_counts(normalize=True).loc[0]
# Out:
# 0.9241257156979857
